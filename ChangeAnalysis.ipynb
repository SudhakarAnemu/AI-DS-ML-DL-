# %% [markdown]
# <a href="https://colab.research.google.com/github/SudhakarAnemu/AI-DS-ML-DL/blob/master/ChangeAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imporitng all required packages
# <br>useful links
# <br>https://pythonspot.com/read-excel-with-pandas/
# <br>

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
print("Import complete")
# Out:
# Import complete

# %%
# df = pd.read_excel('PRCRINC.xlsx', sheetname='Changes') #not working
df = pd.read_excel('PRCRINC.xlsx')

# %%
df.head()
# Out:
#    Change ID     Scheduled Start  ... Risk Level             Impact
# 0  CRQ123489 2013-08-15 11:00:00  ...        1.0  4-Minor/Localized
# 1  CRQ127982 2013-09-26 09:30:00  ...        1.0  4-Minor/Localized
# 2  CRQ132402 2013-11-02 10:00:00  ...        1.0  4-Minor/Localized
# 3  CRQ143119 2014-02-18 15:00:00  ...        1.0  4-Minor/Localized
# 4  CRQ143868 2014-02-25 13:15:00  ...        1.0  4-Minor/Localized
#
# [5 rows x 17 columns]

# %%
df.dtypes
# Out:
# Change ID                        object
# Scheduled Start          datetime64[ns]
# Status                           object
# Summary                          object
# Assignee                         object
# Change Manager                   object
# Assignee Group                   object
# Affected Parties                 object
# Notes                            object
# Scheduled Outage                 object
# Submitted                datetime64[ns]
# Requestor                        object
# Scheduled Duration               object
# Change Timing                    object
# Categorization Tier 2            object
# Risk Level                      float64
# Impact                           object
# dtype: object

# %%
df.shape
# Out:
# (489, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Change ID     Scheduled Start  ... Risk Level             Impact
# 0    CRQ123489 2013-08-15 11:00:00  ...        1.0  4-Minor/Localized
# 1    CRQ127982 2013-09-26 09:30:00  ...        1.0  4-Minor/Localized
# 2    CRQ132402 2013-11-02 10:00:00  ...        1.0  4-Minor/Localized
# 3    CRQ143119 2014-02-18 15:00:00  ...        1.0  4-Minor/Localized
# 4    CRQ143868 2014-02-25 13:15:00  ...        1.0  4-Minor/Localized
# ..         ...                 ...  ...        ...                ...
# 484  CRQ353387                 NaT  ...        1.0  4-Minor/Localized
# 485  CRQ271473                 NaT  ...        1.0  4-Minor/Localized
# 486  CRQ373203                 NaT  ...        1.0  4-Minor/Localized
# 487  CRQ373528                 NaT  ...        1.0  4-Minor/Localized
# 488  CRQ363242                 NaT  ...        1.0  4-Minor/Localized
#
# [489 rows x 17 columns]>

# %%
df.isnull().sum()
# Out:
# Change ID                  3
# Scheduled Start          134
# Status                     3
# Summary                    3
# Assignee                   9
# Change Manager             3
# Assignee Group             3
# Affected Parties          14
# Notes                      3
# Scheduled Outage           6
# Submitted                  3
# Requestor                  3
# Scheduled Duration         3
# Change Timing              3
# Categorization Tier 2      3
# Risk Level                 3
# Impact                     3
# dtype: int64

# %%
df.describe()
# Out:
#        Risk Level
# count  486.000000
# mean     1.065844
# std      0.351412
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      5.000000

# %%
for i in df.columns:
  print(300*'*')
  print("Name of the column : ", i)
  print("Unique Values : ", df[i].unique())
# Out:
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Summary
# Unique Values :  ['Data Updates to be done to the TRPS_WO table to resolve data issues'
#  'Add logic to provide separate counts for rep/nonrep lost/restricted days'
#  'MKS: 489466 Dispatcher Daylight Savings Fall Back Chgs'
#  'Restart troux service in Production environment.'
#  'fix broken ticket that is abending in PROD'
#  'Lower Procard input threshold' 'MKS# changes for work train pop up 1'
#  'MKS# Changes for work train pop up 1' 'Control-M Scheduling Update.'
#  'Server memory install' 'CA code MR changes' 'Prod Fix'
#  'Adding new fields to QTDEMO3' 'To Install Package JDXR2680 and JDXR2683'
#  'vmlxphmd001 firewall port changes'
#  'Please create following indexes in Prod database  Sourcedb: MZT03000  Targetdb: MZP03000'
#  'Add TOPSEARCH02.bnsf.com at 10.6.45.38 to the F5 Pool with low priority and disabled.'
#  'To successfully install changeman package MDXX000558'
#  'MKS 690357 - LCMS Engg Claims Ability to add Claimants not in Active Directory (Retired employees)'
#  'Move real estate GIS application to production'
#  'Fix for L:ogmaster job OTCRWHI0' 'Scratch CTTNMQ01 fro OT-PAYRL'
#  'Edit Fuel application script files, property files ,crontab and remove log files on ftwaxbwap005.'
#  'Restart Sabrix' 'TEST' 'SAP 2016 Minor 1 Release'
#  'Sabrix dataset recreation' 'Test Weekly Release - No change'
#  'Hierarchy box' 'SRM UI First MVP productio deployment'
#  'The change description would be for clean-up of orphaned accounts in SAP.'
#  'Remove MMRGRCYA from CA7 scheduling'
#  'Code SP - hard-coding for 19100-19100 for SANBER-BARSCA trip rates and WCLBAR trains'
#  'AT&T DAS -Distributed Antenna System (cellular) Ft Worth campus outage due to maintenance'
#  'Remove following jobs from CA7 scheduled production.  MMRGRCBU MMWEB31 MMWEB30'
#  'Remove MMCREW50 and MMCRWP from CA7 production scheduling'
#  'Enable Yammer file attachments and pictures' 'CA-7 New Request'
#  'UMLER 17.3 production move - web changes'
#  'AT&T Trackside APN  Billing Sweep' 'Change MMLWEBB to "Call after 8"'
#  'Remove MMLWEBB as a part of DPR@0415' 'Customer Portal Release Updates'
#  'failover QC3 from toplxsapr054 to toplxsapr055'
#  'DVM Archiving of ZCATS Data 2009'
#  'Upgrade IOS txftwnocxp-sc494ad0181 & txftwnocxp-sc494ad0182'
#  'please upgrade Centrify  Agent to version 5.4.3. on the following servers ftwlxsapr425,426,427.'
#  'Assignment events - for Modernization team'
#  'What:  Implement SAP Recommended change To SAP CLM PC1 Production    THIS IS Dynamic'
#  "AT&T Metrocell's  SW upgrade  at OSB on the 9th of February between 12midnight and 6am.."
#  'Modify  local page customization setting to not allow users to edit insurance approved field'
#  'EME1035 add logic to WBMPTED to relay EDO message over MQ to SRM'
#  'Add ZZ32 and ZZ50 to MISC EQP GRP'
#  'Add ZZ32 and ZZ50 to MISC EQP GRP in PROD'
#  'ALK v24.0 1.7 Upgrade (web services)' 'Test for Audit'
#  'SELinux Soluitioning on ftwlxdevd001'
#  'GMSB125C - New GMS connect test process'
#  'Change GMS125, GMS125T, GMS520T and GMS540T to use the QT Cutoff table instead of CT.Payroll_cut'
#  'Disable taxable SAP transaction for Sabrix outage on Sunday June 10th'
#  'YDH - Include Crew Names'
#  'MobileIron Core Server 1 - Upgrade to 9.7.0.1'
#  'MISC Attachment recipient change' 'Config change on toplxgeop001'
#  'Jenkins restart' 'VTS Release 18.15a' 'VTS Release 18.17'
#  'EBIS MF DB2 Invoice Delete'
#  'Network connect new servers supporting Tech M EUC transition'
#  'nothing changed 2' 'dataset record deleted for abend AFRDBL02'
#  'CA-7 Update Existing Job on jobs detailed in task documentation'
#  'Verizon Locomotive APN: Adding a new subnet to BNSFCTWO (10.145.32.0/20)'
#  'Citrix WEM Upgrade'
#  'Deploy https://github.bnsf.com/XF/ct-contingency-processor.git'
#  'ChangeMan  Description - MMXU005692'
#  'KAFKA upgrade to Confluent-5.1.0 in PROD'
#  'Decommission Obsolete Revenue Jobs'
#  'AWI-Clear bad City name and user ID corresponding to user ID F21620 having pattern ID as 1054290. Al'
#  'Add New TACACS Server Key to Network Devices'
#  'Add New Network Management Subnet to Network Device ACLs'
#  'PS1814 CRB Dev DB Migration - crbd4000 : April 29th'
#  'Upgrade JAVA component  SERVICECORE to  to resolve certificate issue  for DocuSign project'
#  'Add ftwwdwkip001 ref WO0000000508357 - DHS Request'
#  'Add ftwlxedpp005 ref WO0000000510935 - DHS Request'
#  'EBIS - Unassign issue fix' 'Testing Only'
#  'SP292  Adding Sherris Email-Id  removing Harrys Email-Id from close and Preclose Reports.'
#  'Encryption Project - R3R table changes'
#  'FTW_SVC_03 - Migrate the LUNs from Tier 2 (XIV) to Tier 1 (Flash Storage)'
#  'Add ftwlxudsd001 ref WO0000000515763 - DHS Request'
#  'Add 2 WFE Servers to SharePoint Prod 2013'
#  'Deploy https://github.bnsf.com/XF/ct-trip-shift-order-processor.git'
#  'Update properties file for DOA issue in LR' 'Natural Template'
#  'OHMAINT 9 switch for dwell, delay' 'OM-TTRN_LINEUP + _HIST'
#  'PTC Asset View for publish' '2019.2 RipTrack Masters Sprint 3.1 Release'
#  'Ft Worth TX Move Kleinschmidt IPSec Tunnels to ASA'
#  'ChangeMan  Description - MMXU005718'
#  'Need access to Insert records for COT.TCOT_CUST_GRP'
#  'Add toplxrimp003 ref WO0000000522414 - DHS Request'
#  'Add ftwlxlssr001 ref WO0000000523508 - DHS Request'
#  'Add toplxlssp001 ref WO0000000523930 - DHS Request'
#  'Add toplxlssp002 ref WO0000000524066 - DHS Request'
#  'New module to forward NT and NF 322s at NWOHIICTF'
#  'Disable Tibco bridge for GPS and CAD messages'
#  'FTW SVC - Need to reboot all nodes (One at a time) in Forth Worth SVC'
#  'Netapp luns creation request on Toeaka'
#  'Load balncing within the aggreagates in FTW'
#  'implementing Domain autentication in NAS environment'
#  'Modify for topwdadfp001 ref WO0000000529238 - DHS Request'
#  'Add ftwlxgisp003 ref WO0000000530841 - DHS Request'
#  'Add toplxgisp003 ref WO0000000530842 - DHS Request'
#  'Add toplxgisp004 ref WO0000000530845 - DHS Request'
#  'Add ftwlxgisp004 ref WO0000000530802 - DHS Request' 'ABS433L  bug fix'
#  'Change PW for SQL Login' 'ISL - Data Encryption changes'
#  'Add ftwlxmtrq001 ref WO0000000531529 - DHS Request'
#  'Add ftwlxmtrq002 ref WO0000000531530 - DHS Request'
#  'Wayside maintenance for Red rock and Ft Worth sub from Alliance yard to Marietta.'
#  'Update DHS RHEL templates to JuLy 2019 Version on FTW & TOP regions.'
#  'ADAPT back ground MF modules'
#  'Add toplxcsrp001 ref WO0000000533897 - DHS Request'
#  'Add ftwlxcsrr001 ref WO0000000533898 - DHS Request'
#  'Add ftwlxcsrr002 ref WO0000000534025 - DHS Request'
#  'Add toplxcsrp002 ref WO0000000534109 - DHS Request'
#  'Dataset change - ABS.PROD'
#  'Deploy https://github.bnsf.com/XF/bnsf-remedy-common-integration-test'
#  'PM GTC Denver 38th Street'
#  'Edgerton, KS (LPKC) Apply Multicast to Routers'
#  'Add ftwlxesep001 ref WO0000000538030 - DHS Request'
#  'Dispose Topeka Pureflex Chassis'
#  'Add topwdsqlp006 ref WO0000000540319 - DHS Request' 'Globeville GTC PM'
#  'Rebuild Secure Store in SP 2016 Prod' 'TechM Avaya Core Switch Change'
#  'Removal of iOS label from Workforce HUB APP' 'CA-7 Update Existing Job'
#  'Update and install Tanium Lab environment' 'MobileIron Core1 Update'
#  'cwe temp table changes issue fix'
#  'ChangeMan  Description - Move AYXX000041'
#  'Move program and jcl changes to process RLR rows from parallel'
#  'servers disk timeout  change setting'
#  'ChangeMan  Description -   Add  Drug and Alcohol link to Supplier Portal'
#  'RIDE Jenkins Deployment ct-trip-request-processor.git'
#  'Add topwdtvep006 ref WO0000000549003 - DHS Request' 'Delete incompletes'
#  'MOVESYS to Remedy Audit Test' 'RIDE Jenkins Deployment ct-webui-bff.git'
#  'RIDE Jenkins Deployment ct-mobile-bff.git'
#  'INC000002932260 - Discontinue "BNSF RWY Customer Contact Verification" Automated Email'
#  'Decommission IA batch from old bwap server and DClocator batch from both old and new servers'
#  'Install Onetime File delete job'
#  'AFCAS Decommissioning - SRC/ISR/DBRPKG/LOD/LST/DBB/BND - 4'
#  'AFCAS - COPYLIB Decommissioning'
#  'Upgrading application to Java 1.7 compatibility.' 'DPR dataset change'
#  'Taking Wash & ADLI network down, including Cambium, Switch (mthvrdepxp-sc356001 10.173.137.242), APs'
#  'RIDE Jenkins Deployment ct-vendor-output.git'
#  'Gathering Prerequisites for DB2  V11.5-SB38986  Install New Linux Purescale Sandbox Servers'
#  'SEP Anti-Virus Testing Deployment'
#  'CDMT-Dispute scorecard new- Add edits to prevent array out of index error in MF side.'
#  'Add toplxtfsp001 ref WO0000000555040 - DHS Request'
#  'BNSF Production computers that meet the 30/60 criteria for disable/delete.'
#  'Supplier Portal Update in support of Sap supplier upgrades'
#  'Add toplxbbsp001 ref WO0000000555164 - DHS Request'
#  'Implement the Enhancements for TMPE'
#  'Update Supplier Portal with new SAP Links,  Add new purchase commodities links'
#  'Promote latest STAMP build to production' 'Intel security patching'
#  'TrainSchedule Production release 19.22'
#  'Changes to retrieve fuel levels using Fuel Service'
#  'Switch to turn on logic for Fuel Level Service changes'
#  'Supplier Portal Updates for SAP' 'Planned Outage with RCX'
#  'Fix Prod Problem in OASPIGAT'
#  'Conduct IVP testing on new PureScale Dev Linux cluster'
#  'Control-M Delete ED-P-SFTP-EDEMDDS2-J'
#  'Control-M Delete ED-P-SFTP-EDEMDDS3-J' 'New job EDEMMETR'
#  'Los Angeles, CA - WWTP Adding expansion module to IE3000'
#  'Add ftwwdspep002 ref WO0000000557002 - DHS Request'
#  'Add topwdspep001 ref WO0000000557312 - DHS Request'
#  'Add topwdspep002 ref WO0000000557232 - DHS Request'
#  'Installing Spectrum control application in Linux server TOPLXTPMP001'
#  'Add ftwwdclkr002 ref WO0000000557250 - DHS Request'
#  'Work on Building New pureScale Linux Dev Cluster'
#  'Decommission/Dispose ftwlxpasn033 DC020115 WO554663.'
#  'Decommission/Dispose ftwlxpasd021 DC020114 WO554664.'
#  'Decommission/Dispose ftwlxpasd016 DC020113 WO554734.'
#  'Install tsm 8.1.7 -TIV-TSMBAC-LinuxX86 client on ftwlxtwrd002' 'TEST..'
#  'Weekly Production IMS FORMAT & ACB Swaps For C, E, G, H'
#  'Changes collected over Peak Time 2019'
#  'Weekly BAU DBA Maintenance - 12/02/19'
#  'Insert rows into TRPM_WRKLST_PA_PRC to be picked up by the nightly DW feed to correct missing static'
#  'Table Change - Midtier - CCure' 'VRU database changes movement'
#  'Applying CSD Security Patches on Linux Non-Prod servers Please .see notes'
#  'ESXi host patching upgrade to EP15'
#  'Deploy CSA check box fix to production' 'B-178189 - Anchor Conversion'
#  'Production Move. Fix for ICP and LTI forms'
#  'Applying CSD Security Patches on Linux Non-Prod servers Please see notes'
#  'NX GoLive in Amarillo'
#  'GSD required health checking and password changes on IBM Cisco switches.'
#  'Control-m for customer portal data ingestion'
#  "Change J.B Hunt split rate control card to point 19' split rates"
#  'Install --BNSF MidTier HANA Production Policy 1.3'
#  'Enable system state backup - WO0000000557710 -See Notes'
#  'Deprovision ftwlxpasr023 DC020146 WO556141'
#  'Deprovision ftwlxpasr029 DC020147 WO556097'
#  'Deprovision ftwlxsbit001 DC020151 WO556117'
#  'Deprovision ftwlxpasr022 DC020145 WO556140'
#  'B-178367_SMART - Price overflow - Data restore for CP & Coal Price'
#  'Installation of ClassOne Console - St. Joseph, MO'
#  'Scheduling Control-M Jobs in EN-P-GEOCARBATCH'
#  'Total Rewards - Employee Election value update'
#  'Ft Worth TSOC LAB - Enable Jumbo Frames on lab firewall'
#  'Topeka KS Update Received Routes from Azure for Cloud Project'
#  'Disable the task in task scheduler -See notes.'
#  'Event Code Promotion to Hadoop'
#  'Add CTM Jobs to Ingestion Folder (HD-P-OPS-MECH-MAM-SAP) and Event Folder (HD-P-OPS-MECH-MAM-EVENT).'
#  'FTWSVC03:-Renaming of NON Replicating luns.'
#  'TeaLeaf - employee.bnsf.com cert file'
#  'PS-1903 - LiveSite Installation on TOPLXLSSP002'
#  'Add firewall rule to allow Icomera to reach internal server topwdfmsp001'
#  'Maintenance at 2E  Switch Affected: kskcktwrxp-sc375027 10.120.217.235'
#  nan 'ksovpttcxp-fp850001 : add firewall rules'
#  'FT Worth TX - CBM - Add ping test policy for all sites'
#  'TOP TOR R-341/R-342 Install'
#  'Deprovision ftwwdemad001 DC020120 VM WO0000000555447'
#  'Deploy MTR Training to Mobile Iron core 1 and 2'
#  'Applying CSD Security Package on Linux Non-Prod servers Please see notes'
#  'WO0000000557703 2Group -> (SC#99)UNIX--Other (IGS Dispatcher)'
#  'ITSM Change - Modify Popup Message For 24 Hour Expedited CRQs'
#  'We will PM CTC wayside radios at Pittsburg/Pittsburg west/Sando west.'
#  'Wishram SBA Replacement'
#  'To update the contact email id and To update the filewatcher wait time for net net process.'
#  'Rename servers as per WO557119 - Rename ftwlxbbst003 to ftwlxbbst001'
#  'Deprovision ftwwdsbid004 DC020129 VM WO0000000556063'
#  'Deprovision ftwwdopmd001 DC020130 VM WO0000000556375'
#  'XAB1: Install Annual Vanguard License Key'
#  'To edit the permissible values in TF_ELE_VALID_VAL table for Umler 19.4 implementation'
#  'Weekly BAU IMS Gens for Development' 'Weekly_Release_12/04/2019'
#  'TELPROD - Sync Servers and Flush Mid-Tier Cache'
#  'WO0000000557762 2Group -> (SC#16)MQ Requests - Queue for Train Schedules 2.0'
#  'Tipping Point IPS Devices, Update Digital Vaccines'
#  'change natnitf1 to natnmntr for loco transactions'
#  'TO CHANGE THE IMS TRANSACTION FROM NATNITF1 & NATNMEVT, WHICH ARE    SHARED, TO NATNIBMH SO OUR PROG'
#  'Wishram Users Move to SBA' 'Deprovision ftwlxpasr028 DC020135 WO556144'
#  'Deprovision ftwlxpasr031 DC020136 WO556145'
#  'Deprovision ftwlxpasr026 DC020134 WO556142'
#  'ISIM Prod, TOP and FTW server config update for autom provision to SAP Sol Man.'
#  'NICE Vision Topeka, KS AMS Update'
#  'Success Factors Vendor maintenance - EC & LMS outage'
#  'Install Guardium GPU 10.6 patches.' 'Sunday TSS BAU Outage - 12/08/19'
#  'Weekly BAU DBA Maintenance - 12/09/19'
#  'Deprovision toplxtemp002 DC020132 WO555169'
#  'Deprovision toplxtemp004 DC020133 WO555171'
#  'Phased Deployment of Feature update 1903 to  standard Production Windows 10(approx. 2000 devices'
#  'Scratch old Method Handler with their associated components'
#  'Take a full backup of AH DB Prod (enp02000.db.bnsf.com) Dec 11th at 5:00 PM and save it.'
#  'XAB1: November CIRATS Patching' 'XAB1: IPL Record'
#  'METTS appcycle on toplxwvap008-10 on Dec 14,  2019.'
#  'XAD1: November CIRATS Patching' 'XAD1: IPL Record'
#  'XAC1: November CIRATS Patching' 'XAC1: IPL Record'
#  'Sunday TSS BAU Outage - 12/15/19'
#  'Weekly BAU DBA Maintenance - 12/16/19'
#  'Update CA1 password as required by Customer Security Document every 186 days'
#  'Sunday TSS BAU Outage - 12/22/19' 'XAE1: November CIRATS Patching'
#  'XAE1: IPL Record' 'Weekly BAU DBA Maintenance - 12/23/19'
#  'Change to increase by one (1) GP engine  for each of the TSS processors.'
#  'MICS Software Maintenance -  Version 14.1 (IMS/LDE)'
#  'Update THruput Manager Rules for Weekend Re-orgnizations.'
#  'Implement Trial DB2 (DS1T and DS2T)  for AT-TLS Communications'
#  'Implement Production  DB2 Database (DS0P, DS1P,DS2P,DS3P,DS4P)  for  AT-TLS Communications'
#  'Implement Training and Prep (DS1E, and DS1I) for  AT-TLS Communications'
#  'Implement DS1R AT-TLS Testing'
#  'Implement Development DB2 (DS1D) AT-TLS Communications'
#  'Implement QUAL and VALI (DS1Q and DS1V)  for AT-TLS Communications'
#  'Update THruput Manager Jobs table for WBOWRDW'
#  'Sunday TSS BAU Outage - 12/29/19' 'XAG1: IPL Record'
#  'XAG1: November CIRATS Patching'
#  'Implement Product Keys for TSS CPU Upgrade' 'XAH1: IPL Record'
#  'XAH1: November CIRATS Patching' 'Weekly BAU DBA Maintenance - 12/30/19'
#  'METTS appcycle on toplxwvap008-10 on Dec 31,  2019.'
#  'XAC1-DS0R PowerExchange - PWXLST2R V10.2.0 Hotfix2 Migration For SAP only - PWX102H2'
#  'XAH1-DS0P PowerExchange - PWXLST2P V10.2.0 Hotfix2 Migration For SAP only - PWX102H2'
#  'Sunday TSS BAU Outage - 01/05/20'
#  'New base view and modified public view for OAS_UNIT_DATA table'
#  'PROD - SwitchPlanner - create table and grant privileges'
#  'Klamath Falls Users Move to SBA'
#  'Scratch Set of Unused EDO Components related to the obsolete process called SCOOP, in order to Reduc'
#  'RTE JCL cleanup' 'Train Sheets MQ: Migrate TS Exit Messages'
#  'Enable Densify SLC Rules on FTW-DMZ-01 Cluster'
#  'Enable Densify SLC Rules on TOP-DMZ-01 Cluster'
#  'Drv code load from 32 to 36 on z1401 an z1402'
#  'Drop RT schema in DS1R; free any lingering plan/pkg'
#  'Topeka KS - COB - Install POD2 leaf group switches 7-9'
#  'CAS decommission'
#  'E-26941 - logic to allow to create payable chargeback events manually'
#  'Drv code load from 32 to 36 on z1403 an z1404 and z1405'
#  'Cut over from 6509 SW-TOP-CIS6509-2 to 9407 SW-TOP-CIS9407-2'
#  'Cut over from 6509 SW-TOP-CIS6509-1 to 9407 SW-TOP-CIS9407-1'
#  'Matl Sc Changes - Control-M New Schedule'
#  'Control-M Scheduling Update - Action Plan table load'
#  'Control-M Scheduling Update - DOT Changes' 'update dataset'
#  'DVM Archiving of CATSDB data for 2010, 2011'
#  'DVM Archiving for PA_TIME/CALC'
#  'EHS-STAR Phase 2 - Control M job for claim and document'
#  'Remove from CA7 scheduling:  MMLCMDTY MMLCNTS MMLDHSMY MMLI5CNT MMLI5RPT MMLOCRMT MMSTAT80 MMSTAT90'
#  'Scaled down openshift production pod for Crew Planning application.'
#  'MKS 647218 - move latest build of DetPay to production'
#  'Data Change - viewed QT.PROD.HWF.DIVISION'
#  'MKS#376173 - Code CS on K trains' 'MKS# 552184 - Work Train Pop up'
#  'MKS#376173 - Code CS for K trains'
#  'restart crewplanning-new memory exhausted' 'restart crewplanning_new'
#  'Data Change - UW Eventing tables' 'Test move'
#  'Setup CA7 schedule for Dispatcher Push Notification'
#  'Push CAPTCHA and Web-to-Lead for Public Ag Pricing functionality.'
#  'Railinc File Cleanup'
#  'Teradata NPARC after hardware upgrade on 9/16 there will be a second data copy on 9/17'
#  'CA-7 New Request HDEMA01X daily'
#  'Control-M Scheduling Update CW-P-INFA-DW_-MECH modifying warn bearing and edr to run earlier'
#  'XA?1-DS1?  DB2 V10 MIGRATION TO CM Mode - DBA110M'
#  'XAC1-DS0R  DB2 NGT - V12.1 Migration  - NGTC01M'
#  'TEMPLATE XA?1-DS1?  IBM - InfoSphere Replication Server for z/OS V10 - DPA101M'
#  'XAB1-DS1Q CA Report Facility for CICS,IMS, TSO R20 Maintenance  - PR20SP3'
#  'XAB1-DS0D Re-Create the production problem with NGT REORG/Powerexchange. Setup SLIP TRAP.'
#  'XAC1-DS1R ESS  CA Report Facility for CICS,IMS,  TSO R20 Maintenance - PR20SP4'
#  'XAC1-DS0P TSS CA Report Facility for CICS,IMS, TSO R20  Maintenance - PR20SP4'
#  'XAC1/XAE1/XAE1/XAH1-DS0P DB2 BMCV12.1 products migration stage 2 - BMCC01M'
#  'XA?1-DS?? DSNZPARM xxxxxxxx from xx to xx going in with IPL'
#  'Schedule ZCPWXPICC'
#  'XAB1-DS0I/DS0D/  DB2 NGT - V12.1 Migration  - NGTC01M'
#  'Adding Image copies for Misc Backup Jobs'
#  'Create new Image copies for Misc databases'
#  'AT&T Metrocells turn down to do Site Survey for DAS at 14900 John Day Rd, Haslet, TX'
#  '***Change Template' '____Template_____' '>>>  CHANGE TEMPLATE  <<<'
#  'CRQ TEMPLATE' 'Migrate TEMPLATE to Skype for Business'
#  'MechCar: remove a program that is a duplicate in name, across 2 libraries'
#  'MechCar: Add back in the 9004 Update' 'remove hint and move to prod'
#  'Enable "Reactivate suspended users" feature on GitHub'
#  'Thales/Gemalto non-disruptive maintenance for SafeNet Authentication Service Cloud Infrastructure'
#  'Update data source & connection pool settings for GOP & NEP Websphere apps Tier 1.'
#  'Deploy RPA Finance_CRF_UmlerExcel_Dispatcher and Finance_CRF_UmlerExcel_Performer'
#  'Deploy AUDIO module to Northtown NP1-NP4'
#  'DRAFT: Add the new servers to TSM backup, ITM Monitoring  and  Netcool DB'
#  'Access to ODS tables' 'Migrate VMWDSQLP012' 'Crew table changes to DW'
#  'Turning Ride on in Prod'
#  "Display 'ED' delay code under terminal in division pages"
#  'MT needs to be added to PII approved list'
#  'Install smtp2sms on toplxmobp001/2 to implement Everbridge.'
#  'Install smtp2notify on toplxmobp001/2 to test Everbridge.'
#  'Install smtp2notify on toplxmobp001/2 to test Everbridge'
#  'PTC Virtual Environment Maintenance'
#  'EME6232 - Daily Mark called from brd 56'
#  'MAINT - Trainsheet ID correction when the message is passed from crew swap to CAD'
#  'Table Change - Midtier'
#  'Add language and redirects to help customer portal users with outdated bookmarks.'
#  'CIRATS  107504992 - Oracle PSUOct2019 patch on toplxorap008'
#  'CIRATS  107504992 - Oracle PSUOct2019 patch on toplxorap007'
#  'CIRATS  107504992 - Oracle PSUOct2019 patch on toplxorap009'
#  'Mincom Ellipse - Update Zero Dollar Stock Items with 0 SOH'
#  'Production Dataset updates for fixing a on call issue'
#  'For fixing issues with year end' 'ARI - Vendor Payment Terms changes'
#  'GI - SAC Segment handling in fuel Invoices and Item description fix'
#  'Production fix on job IMDA1070'
#  'ADP - One time updates to field rail table for the Division Number'
#  'To fix Production job abend - IMDA1030'
#  'BNSF Logistics - to include AFE and Cost Center'
#  'Updates to MSF900 table'
#  'ADP Data change - To correct Incorrect Patron Number on an Invoice'
#  'Data Updates to MSF013 table - As part of HST changes'
#  'Updates to Prodcution Datasets as part of production issues during go-live implementation'
#  'For fixing production job abend IMDA1030'
#  'To Install ChangeMan Package JDXR2707' 'MobileIron Core2 Server Update'
#  'MobileIron Server Core 2 upgrade to 9.7.0.1'
#  'Add WAIT (YES) to Boole Exec for Sunday Prod Natural Moves'
#  'State City, Site Firewalls Test Failover' 'Change Template'
#  'Train control firewall - custom app or app override written'
#  'Code Change' 'Cleanup a few User IDs from PowerPlant PROD database'
#  'NOCPTC-RPTDBS1(10.50.39.187) - Need 500G of additional storage space'
#  'Data Encryption - R3R data change' 'Haulage GitHub Security remediation'
#  'Major2 Hypercare-Please approve the move for 8000003871-Supplier Portal: Payment Inquiry, to Prod'
#  'Creation of LR auto restart process'
#  'TOP SVC - Allocate 50 GB X 4 LUNs to the "topaxorap010" server from Tier-1 pool'
#  'TOP SVC - Expand 2 LUNs mentioned in the notes by 200 GB'
#  'creation of new FS for Jenkins app due to perf issues with nfs . inc  1957869'
#  'Code upgrade of TOPSNFSHP001 from 1.4.6.1 to 1.5.2.6'
#  'Code upgrade of FTWSNFSHP001 from 1.4.6.1 to 1.5.2.6'
#  'Grant read/write access to bodsdm01/bodsdm02 on BODS production database in topaxclmp001 server.'
#  'UNIX team please switch PC1 toplxsapp055 cluster node to Normal from maintenance'
#  'Perform full database Export of PC1/PC2'
#  'Restarting Java Services for CLM production due to TAM  installation this morning'
#  'Removing CTS_PLUG' 'Setup Auto-Delete for PL_LDOC Archiving'
#  'Archive 2012 payroll data in PE1'
#  'Need SAP PE1 access for B021715 (same as B025083)'
#  'Kindly move AP007 Estimated liabilities TS report from QA to P'
#  's Grant Access to Andy and Brad on Ceredian and ERCDECOM Databases on TOPWVSQLP107\\SQLFNCE06'
#  'Install FireEye HX Client on IBM Engineering servers'
#  'F5 Update for new DNS entry'
#  'Ft Worth TX Move Progress Rail IPSec Tunnel to ASA'
#  'Remediate TKLM Cirats on toplxtkmp001. ftwlxtkmp001, BLDLXTKMP001 and BLDLXTKMP002'
#  'Switch off TrainRules 2.0 after production code bug identified.'
#  'Update SRM agent on SAP HANA Non-Prod server'
#  'MVS ALL: upgrade SYNCSORT to v3.1']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Assignee
# Unique Values :  ['Felisha L Washington' 'Danielle M Stewart' 'John E Schneider'
#  'Janet E Perry' 'Aaron E Cook' 'Samuel Zakster' 'Benjamin Stroik'
#  'Christian Coon' 'Gejarajan Karthikeyan' 'Kira Hall' 'Gary R Tobin'
#  'Srilakshmi Tayi' 'Alok Bhaskar' 'Carolyn M Liles' 'Allan Greif' nan
#  'Zhijun Zou' 'Shalu Soman' 'Madhavi Reddy' 'Aaron S Betts'
#  'Cindy K Wininger' 'Tomi P Karhu' 'Sankar A Jankoti' 'Michael T Butler'
#  'Lisa M Fisher' 'Vipin Kohale' 'Gary Jones' 'Larry G Trautman'
#  'Sunil K Bhuvanagiri' 'Dionne S Johnson' 'Ryan Hansen'
#  'Sandra L Fountain' 'Colin Benefiel' 'Jonathan Oladimeji' 'Daniel Mendez'
#  'Khaldoun Alnachoukati' 'Byron K LeBlanc' 'Jonathan A Milton'
#  'Thomas F Maahs' 'Richard G Poirier' 'James T Wyatt' 'Jason Fowler'
#  'Ganesh Narayanaswami' 'Sayan Dawn' 'Robert L Wallace'
#  'Murali a Chellamuthu' 'Anthony M Fernandez' 'Ken S Berg' 'Garry Nelson'
#  'Shanmugasundaram Rajasubramanian' 'Nicolas M Leon Vazquez'
#  'MP Automation' 'Larry D Smith' 'Cecil L Noble' 'Linda A Youngblood'
#  'Jitendra Chevuru' 'Mohammad Wasim' 'Sneha Korishettar' 'DHS Automation'
#  'James F Ward' 'Gaurang D Yengal' 'Revathy Subash Chandrabose'
#  'Avijeet Deogharia' 'Brian J Cattle' 'Nikhil Deshpande'
#  'Carolyn S Kamperman' 'Bob L Titiryn' 'Jason M Green'
#  'Sanoj J Pulicodan david' 'Aaron C Cary' 'Kasiviswanathan Vijayakumar'
#  'Liam T Gartside' 'Sebabrata Mandal' 'Rajasekhar R Katlla'
#  'Ramalingam Palanivelu' 'Venkata Appa Rao Sudina' 'Frank G Kren'
#  'Ayusmita Das' 'Lance D Dang' 'Kevin S Amundson'
#  'Douglas Solis Benavides' 'Naresh Gokara' 'Derrick Williams'
#  'Janet A Lenherr' 'Scott M Alexander' 'Thomas Kenney'
#  'Karthikeyan Arumugam' 'Konnie Espanet' 'Sivasubramanian Velusamy'
#  'Vinod K Ganeshan' 'Simon A Nelson' 'Jose M Soria' 'Benjamin Molenda'
#  'Ride Automation' 'Radhika Katragadda' 'Bruce D Kamp'
#  'Dinesh K Ashok kumar' 'Len A Williams' 'Karthick Sugumar'
#  'Francis S Polisetty' 'Naveenkumar Ammasaigounder Somasundaram'
#  'Sandeep R Poreddy' 'Bayne A Smallwood' 'Vaideeshwaran Chinnathambi'
#  'David J Kentala' 'Michael J Ivey' 'Ahammedkabeer Abdulla'
#  'Muniraja Chinakanamgu' 'Shriom Purbey' 'Michael Duke' 'Jeff A Carne'
#  'Gary W Duke' 'Michael Patak' 'Shineesh Pashnom Kandiyil'
#  'Senthilnathan Rajappa' 'Hassan I Hamid' 'Sai V Kothapalli'
#  'Saninath M Palchuri' 'Jaime Ruiz' 'Harry L Leonetti' 'Niket B Shah'
#  'Helen L Presley' 'Nagamani Varatharaj' 'Manimaran Ganesan'
#  'Marutha p Jagadesan' 'Marcus G Clay' 'Swarna S Lingesan'
#  'Preethi Sridharan' 'Todd E Millam' 'Krishna K Shukla' 'Parag B Junghare'
#  'Tushar S Negi' 'Nicholas Roush' 'Steven R Williams' 'Daniel R Davis'
#  'Glen A Jones' 'Jason C Bowen' 'Mikael D Ouellette'
#  'Dinakaran Velmurugan' 'David A Cowles' 'Premanand Rajendravarathan'
#  'Sudhakar Anemu' 'Eric R Phillips' 'Kara A Verbeek' 'Harsha Kumar'
#  'Nalan Sambantham' 'Roger M Predatsch' 'Rajapriya Kuppa Sadhahari'
#  'Sivaranjani Sivasankaran' 'Julia James'
#  'NetworkSecurityEngineering Automation' 'Cathy L Mccann'
#  'Gregory A Resnick' 'Karthik Viswanath' 'Julia Bueschel' 'Shamsul M Alam'
#  'Vamsikris Vegesna' 'Pamela B Lee' 'Roderick Daniels'
#  'Julie A Mangiameli' 'Jesus M Martinez' 'James W Burnworth'
#  'Shan Y Souders' 'Kelly M Bradley' 'Thomas W Tegtmeier'
#  'Jeffrey J Jordan' 'Nancy C Thornton' 'Patrick E Sbrocca' 'Mark S Arnold'
#  'Greg Harrison' 'Ajay V Chriscoe' 'Ronnald Lambert' 'Marc A Vela'
#  'Jessica M Samuels' 'Kavya Ravi' 'Sivakumar Karuppaiah' 'Wade M Flanagan'
#  'Shobhit Basu' 'Benaiah B Phelps' 'John D Magathan' 'Scott A Miller'
#  'Subbaraju Mamillapalli' 'Jeff L Gales' 'Michael E Williams'
#  'Vikram Krishnan' 'Group Assignee' 'Cruz G Rodriguez' 'Paul D Conn'
#  'Jerry D Fuselier' 'Douglas North' 'Shannon M Stack' 'Kevin J Rinke'
#  'Peter J Tijerina' 'Robyn W Marrs' 'Vijayakumar Krishnan'
#  'Senthilkumar Govindan' 'Steven R Wagner' 'Kendra L Cooper' 'Adam Younes'
#  'Sujan Gautam' 'Dale L Frank' 'Zach Z Smith' 'Brian L Hurla'
#  'Muralidhar Revuri' 'Greg M Kaelin' 'Michael Mcclary' 'Brandon S Walsh'
#  'Rajkumar C Behere' 'Paul B Wallace' 'Judy D Schurle' 'Danny Robbins'
#  'John W Corpany' 'Najmuddin Valika' 'Arun K Babu' 'Yogesh Saray'
#  'Sudarsan Perala' 'Shashidhar Thota' 'James E Montgomery' 'Samuel Ingram'
#  'Steven Martin']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Change Manager
# Unique Values :  ['Felisha L Washington' 'Douglas L Denton' 'Aaron E Cook' 'Janet E Perry'
#  'Giri Amaravadi' 'Ranjish S Kumar' 'Kenny Compton' 'Lisa M Fisher'
#  'Christopher J Ellis' 'Konnie Espanet' 'Daniel Mendez'
#  'Gregory L Palcich' 'Brian L Hurla' 'Kendra L Cooper' 'Jim D DeBacker'
#  'Lux Susarla' 'Vipin Kohale' 'Greg A Cottrell' 'Group Assignee'
#  'Patrick Harper' 'Shawn B Smith' 'Matthew R Sher' 'Thomas F Maahs'
#  'Harry P Mann Iii' 'Keith B Ward' 'Justin B Early' 'Jeffrey D Miller'
#  'Ken S Berg' 'Trey D Edgar' 'Dohrman Wintermute' 'Jitendra Chevuru'
#  'Steven R Wagner' 'MP Automation' 'Robert L Thomas' 'Jonathan S White'
#  'Gary Jones' 'DHS Automation' 'Ranjish S Sukumaran' 'Timothy G Douthit'
#  'Lawrence P Sutton' 'Harry P Mann' 'Douglas D Gruben' 'Reginald J Fultz'
#  'Amy S Allen' 'Charles W Ferrise' 'Grant H Brown' 'Ajay V Chriscoe'
#  'Sam W Phelps-Roper' 'Michael Murphy' 'Viswanathan Ranganathan'
#  'Ravi Goel' 'Janet A Lenherr' 'Karthick Jayaraman' 'Dale L Frank'
#  'Charla M Moore' 'Dillon J Nelson' 'Ride Automation' 'Daniel Allinger'
#  'Sanjay Jain' 'David Pulaski' 'Robert P Cruz' 'Adam Younes'
#  'Mario Hernandez' 'Nick Korsunsky' 'David D Johnson' 'Kirk K Williams'
#  'Ryan R Ramos' 'Lance H Cosby' 'Derk R Hamby' 'Brian H Erickson' nan
#  'Erin j Frank' 'Darrel D Ries' 'Dionne S Johnson' 'Christian Coon'
#  'Timothy J Hodge' 'Troy P Gould' 'Frank E Thomas' 'Jade A Wright'
#  'Mark S Arnold' 'Rahul Zutshi' 'Arrel Rose' 'Kyle Williams'
#  'David E Spotts' 'Timothy L Miller' 'Ed M Gonzalez' 'Lance D Dang'
#  'Zach Z Smith' 'Chad Butler' 'Robert L Beine' 'Sanjay Mallampati']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Assignee Group
# Unique Values :  ['Manager Finance, Real Estate, Property, Resource Protection'
#  'Remedy 7 Support' 'Crew Timekeeping' 'Manager IVR, MKS/Teamplay'
#  'Manager Operating Timekeeping' 'Finance Legacy'
#  'General Sourcing Support' 'Mincom Ellipse - eMESA' 'ESD'
#  'Zephyr Support' 'BNSF.com Solutions' 'Biometrics'
#  'Mapping Services Support' 'Crew TSS Support' 'Fuel Management' 'Tax'
#  'Project Office' 'Release Management'
#  'Manager Business Services, Finance (Legacy)' 'Manager TSS Modernization'
#  'Security & Controls' 'Corporate Measures'
#  'Engineering - Commercial Wireless' 'SharePoint Support'
#  'PTC Back Office' 'Reference Files'
#  'Manager Software Integration Service & Support'
#  'SAP - Basis Production Support' 'CAMPS Support' 'SLS - Telecom Support'
#  'Manager Waybill' 'Natural Support' 'Enterprise Security'
#  'Manager TSS 1.0 Sustainment' 'MOBI Support' 'Engineering Applications'
#  'Enterprise DevOps Support' 'Visual Train Scheduler Support'
#  'Manager Client Tower' 'Revenue Accounting System 1'
#  'BNSF Citrix Support' 'MP Automation' 'Performance Analysis'
#  'Confluent Kafka Support' 'Cost & Profitability'
#  'Manager Revenue - Liability Rating' 'DBA Mid-Tier Oracle'
#  'Cloud Services' 'DHS Automation' 'Non-Ops Timekeeping & Workforce Mgmt'
#  'RAS - MF' 'SAN Support' 'TSS 1.0 Sustainment Support'
# ...
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Requestor
# Unique Values :  ['Sriram Sankaran' 'Natalie Lepsky' 'John Schneider' 'Vick Cox'
#  'Donald Robare' 'James Howington' 'Gaurang Yengal' 'Ishwar Tailor'
#  'Christian Coon' 'Shankari Ramachandrasekaran' 'Srilakshmi Tayi'
#  'Sunil Kankanala' 'Carolyn Liles' 'Baskar Veerappan' 'Zhijun Zou'
#  'Shalu Soman' 'Madhavi Reddy' 'Tipu Khan' 'Cindy Wininger' 'Tomi Karhu'
#  'Sankar Jankoti' 'Michael Butler' 'Cherie Coles' 'Calvin Nguyen'
#  'Bharat Suryavanshi' 'Larry Trautman' 'Sunil Bhuvanagiri'
#  'Dionne Johnson' 'Ryan Hansen' 'Minhaj Muzaffar' 'Colin Benefiel'
#  'Jonathan Oladimeji' 'Dick Waudo' 'Khaldoun Alnachoukati' 'Byron LeBlanc'
#  'Jonathan Milton' 'Thomas Maahs' 'Richard Poirier' 'Alex Volk'
#  'Ganesh Narayanaswami' 'Michael Hart' 'Sayan Dawn' 'Robert Wallace'
#  'Murali Chellamuthu' 'Haritha Alapati' 'Ken Berg' 'Garry Nelson'
#  'Shanmugasundaram Rajasubramanian' 'Nicolas Leon Vazquez' 'MP Automation'
#  'Larry Smith' 'Chandan Kumar' 'Linda Youngblood' 'Dinesh Ashok kumar'
#  'Mohammad Wasim' 'Sneha Korishettar' 'DHS Automation' 'James Ward'
#  'Raghunandan Lingam' 'Revathy Subash Chandrabose' 'Ahammedkabeer Abdulla'
#  'Brian Cattle' 'Nikhil Deshpande' 'Mike Robinson' 'Bob Titiryn'
#  'Jason Green' 'Sanoj Pulicodan David' 'Aaron Cary'
#  'Kasiviswanathan Vijayakumar' 'Liam Gartside' 'Sebabrata Mandal'
#  'Rajasekhar Katlla' 'Ramalingam Palanivelu' 'Sandra Fountain'
#  'Venkata Appa Rao Sudina' 'Jason Norgan' 'Ayusmita Das' 'Michelle Linde'
#  'Kevin Amundson' 'Alejandro Otoya Hernandez' 'Moses Masenda'
#  'Naresh Gokara' 'Derrick Williams' 'Scott Alexander' 'Thomas Kenney'
#  'Karthikeyan Arumugam' 'Len Williams' 'Sivasubramanian Velusamy'
#  'Vinod Ganeshan' 'Simon Nelson' 'Jose Soria' 'Benjamin Molenda'
#  'Ride Automation' 'Radhika Katragadda' 'Bruce Kamp' 'Dinesh Ashok Kumar'
#  'Karthick Sugumar' 'Francis Polisetty'
#  'Naveenkumar Ammasaigounder Somasundaram' 'Sandeep Poreddy'
#  'Bayne Smallwood' 'Vaideeshwaran Chinnathambi' 'David Kentala'
#  'Michael Ivey' 'Muniraja Chinakanamgu' 'Shriom Purbey' 'Michael Duke'
#  'Jeff Carne' 'Gary Duke' 'Michael Patak' 'Shineesh Pashnom Kandiyil'
#  'Senthilnathan Rajappa' 'Hassan Hamid' 'Sai Kothapalli'
#  'Saninath Palchuri' 'Jaime Ruiz' 'Harry Leonetti' 'Niket Shah'
#  'Helen Presley' 'Nagamani Varatharaj' 'Manimaran Ganesan'
#  'Marutha Jagadesan' 'Marcus Clay' 'Swarna Lingesan' 'Preethi Sridharan'
#  'Todd Millam' 'Krishna Shukla' 'Parag Junghare' 'Tushar Negi'
#  'Nicholas Roush' 'Steven Williams' 'Daniel Davis' nan 'Glen Jones'
#  'Jason Bowen' 'Mikael Ouellette' 'Dinakaran Velmurugan' 'David Cowles'
#  'Premanand Rajendravarathan' 'Sudhakar Anemu' 'Eric Phillips'
#  'Kara Verbeek' 'Harsha Kumar' 'Nalan Sambantham' 'Roger Predatsch'
#  'Rajapriya Kuppa Sadhahari' 'Sivaranjani Sivasankaran' 'Julia James'
#  'NetworkSecurityEngineering Automation' 'Cathy McCann' 'Gregory Resnick'
#  'Karthik Viswanath' 'Julia Bueschel' 'Shamsul Alam' 'Vamsikris Vegesna'
#  'Pamela Lee' 'Roderick Daniels' 'Julie Mangiameli' 'Jesus Martinez'
#  'James Burnworth' 'Shan Souders' 'Kelly Bradley' 'Thomas Tegtmeier'
#  'Jeffrey Jordan' 'Nancy Thornton' 'Patrick Sbrocca' 'Mark Arnold'
#  'Greg Harrison' 'Ajay Chriscoe' 'Ronnald Lambert' 'Marc Vela'
#  'Jessica Samuels' 'Kavya Ravi' 'Sivakumar Karuppaiah' 'Wade Flanagan'
#  'Shobhit Basu' 'Benaiah Phelps' 'John Magathan' 'Scott Miller'
#  'Subbaraju Mamillapalli' 'Taylor Harty' 'Jeff Gales' 'Michael Williams'
#  'Kenny Ho' 'Vikram Krishnan' 'Sujan Gautam' 'Cruz Rodriguez' 'Paul Conn'
#  'Jerry Fuselier' 'Douglas North' 'Jason Raymond' 'Kevin Rinke'
#  'Peter Tijerina' 'Robyn Marrs' 'Aaron Betts' 'Kevin Bush'
#  'Pugazhendi Meenakshi sundaram' 'Senthilkumar Govindan' 'Nick Hale'
#  'Adam Younes' 'Dale Frank' 'Mitch Starnes' 'Zach Smith' 'Jon Hass'
#  'Maheedhar Sandadi' 'Zachary Phillips' 'Muralidhar Revuri' 'Allan Greif'
#  'Brandon Walsh' 'Michael Satchell' 'Paul Wallace' 'Judy Schurle'
#  'Kirk Fullerton' 'Jwala Sripathi panditharadhyula' 'Najmuddin Valika'
#  'Rama Tummala' 'Yogesh Saray' 'Tommy Wright' 'Sudarsan Perala'
#  'Gary Jones' 'Shashidhar Thota' 'James Montgomery' 'Samuel Ingram'
#  'Steven Martin']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Scheduled Duration
# Unique Values :  ['8.0 hrs.' '3.5 hrs.' '2.0 hrs.' '.5 hrs.' '16.0 hrs.' '1.5 hrs.'
#  '4.0 hrs.' '1.0 hr.' '1.2 hrs.' '10.0 hrs.' '156.5 hrs.' '23.5 hrs.'
#  '11.0 hrs.' '5.0 hrs.' '2.2 hrs.' '4.1 hrs.' '8640.0 hrs.' '2.5 hrs.'
#  '96.0 hrs.' '17.0 hrs.' '.0 hrs.' '38.0 hrs.' '150.0 hrs.' '25.5 hrs.'
#  '8.5 hrs.' '7.0 hrs.' '7.5 hrs.' '6.5 hrs.' '.9 hrs.' '6.0 hrs.'
#  '9.0 hrs.' '5.5 hrs.' '.2 hrs.' '24.0 hrs.' '11.5 hrs.' '3.0 hrs.'
#  '33.0 hrs.' '9.5 hrs.' '144.0 hrs.' '36.0 hrs.' '24.5 hrs.' '1440.0 hrs.'
#  '42.5 hrs.' '14.5 hrs.' '4705.0 hrs.' '7.3 hrs.' '47.5 hrs.' '78.0 hrs.'
#  '67.0 hrs.' '55.0 hrs.' '.3 hrs.' '.4 hrs.' '272.5 hrs.' '100.0 hrs.'
#  '2737.0 hrs.' '15.0 hrs.' '2137.0 hrs.' '14.0 hrs.' '10.5 hrs.'
#  '89.7 hrs.' '13.5 hrs.' '1373.0 hrs.' '346.0 hrs.' '1926.0 hrs.'
#  '120.0 hrs.' '367.5 hrs.' '29.0 hrs.' '.1 hrs.' '12.4 hrs.' '4.5 hrs.'
#  '439.0 hrs.' '13.0 hrs.' '225.0 hrs.' '321.0 hrs.' '156.0 hrs.'
#  '168.0 hrs.' '103.0 hrs.' '21.0 hrs.' '.7 hrs.' '3.8 hrs.' '63.0 hrs.'
#  '34.0 hrs.' '79.0 hrs.' '82.0 hrs.' '52.0 hrs.' '74.0 hrs.' '128.0 hrs.'
#  '48.0 hrs.' '77.0 hrs.' '32.0 hrs.' nan '19.0 hrs.' '53.0 hrs.'
#  '52.5 hrs.' '126.0 hrs.' '86.0 hrs.' '23.0 hrs.' '81.0 hrs.' '121.0 hrs.'
#  '167.0 hrs.' '22.0 hrs.' '57.0 hrs.']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Change Timing
# Unique Values :  ['Normal' 'Emergency' 'No Impact' 'Expedited' nan 'Latent']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Categorization Tier 2
# Unique Values :  ['RACER' 'Safety' 'Crew Timekeeping' 'Troux' 'Millennium Accounts Payable'
#  'Control-M' 'eMESA Mobile' 'Mincom Ellipse'
#  'Enhanced Service Design (ESD)' 'Customer Relationship Management (CRM)'
#  'Other' 'Claims Management System (CMS)' 'Mapping Services'
#  'Crew Support' 'Fuel Flow Network' 'Accounts Payable' 'Planview'
#  'Weekly Release'
#  'Business & Occupation Tax Reporting for Washington State' 'Coupa'
#  'Shipping Process Management' 'LSO - Learning Solution' 'Equipment'
#  'Router' 'Crew' 'Yammer Support' 'MQ' 'EMIS Web Maintenance'
#  'Network Circuit' 'Locomotive' 'SharePoint Employee Portal'
#  'System Administration' 'Switch' 'Waybill' 'Rail Miles Inquiry' 'Natural'
#  'Tanium' 'AEI - Mainframe' 'MobileIron' 'MR & SA'
#  'Track Testing Interface WEB' 'MKS' 'Visual Train Scheduler (VTS)' 'SCCM'
#  'RAS - Interline Settlement' 'RAS - Misc Billing' 'Other Misc' 'Citrix'
#  'Movement Planner Data Server' 'KAFKA BNSF' 'RAS - Financials'
#  'Automated Waybill Interface' 'Oracle' 'Linux' 'ITSM'
#  'Personnel Activity Tracking System (PATS)' 'RAS - Receivables' 'SAN'
#  'SharePoint' 'Contract Admin Rating & Disbursement (Liability Rating)'
#  'Train Schedule 2.0' 'TSS Train' 'Microsoft .NET' 'DA Services' 'Grain'
#  'RAS - COTS Web Applications' 'TSS Intermodal' 'Train Management'
#  'Windows' 'BI Cost Systems' 'Cad Data Server' 'Interline Subledger (ISL)'
#  'CTC' 'Waybill 2.0' 'Pureflex' 'BI Marketing'
#  'RAS - Rating - Auto & Manual' 'Liability Rating (LR)'
#  'Medical Testing System' 'Revenue Single Source (RSS)'
#  'Intermodal Advisor (PMC)' 'Freight Claims & Damage Control'
#  'BestWay - Scheduler' 'Daily Performance Report (DPR)' 'Cambium IP M/W'
#  'Server' 'BNSF-Windows' 'Customer Dwell Management Tool'
#  'My Expense Transportation (TMPE)' 'Roadway Analysis and Planning System'
#  'Locomotive GPS' 'RIDE' 'IGS DB2 Mid-Tier' 'TSM' 'IMS' 'DB2 Mainframe'
#  'RPMS - Mainframe Batch Processes' 'BI Safety' 'TTIWEB' 'VMware'
#  'RPMS - Web Tools' 'RAPID - Pricing' 'Total Rewards' 'Humpyard System'
#  'VTAM' 'Hadoop' 'Guardium' 'Systematic Marketing & Revenue Tool'
#  'ClassOne' 'Firewall' 'Tableau' 'Customer Web' nan 'MTR' 'Yard Radio'
#  'Skype' 'Car Repair Billing (CRB)' 'z/OS' 'REFERENCEFILES' 'Remedy' 'IPS'
#  'TSS Mechanical' 'Mechanical SAP To TSS Interface'
#  'Identity & Access Management' 'NICE' 'Success Factors eBiz Suite'
#  'Equipment Distribution & Optimization' 'Engineering Asset Hub'
#  'Mechanical Time Tracking System (METTS)' 'Terminal Planner System'
#  'Contract Viewer' 'CAD Train Sheets' 'Mainframe' 'DARS' 'CAS - System'
#  'RAS - Interline Switch Accounting' 'BI Expense' 'Pay Stubs' 'eClaimFile'
#  'CCPLAN-Crew Planning' 'Customer Hub' 'CA7' 'DPR - not measure specific'
#  'Train' 'Access Point' 'SAP - Business Objects  (BOBJ)' 'GitHub'
#  'SafeNet MobilePASS+ (Plus)' 'Pending Grain' 'Technology Management'
#  'DB2 Mid-Tier' 'Crew Vans GPS' 'LMS - Role Changes' 'Everbridge' 'ETMS'
#  'QT - TYE Compensation Systems' 'IGS Oracle' 'Asset Disposition'
#  'Carload' 'PowerPlant' 'Haulage Billing (Receivables)' 'RAS - COTS'
#  'Software' 'Sales & Distribution' 'AntiVirus / Malware'
#  'Portal - Customer' 'Train Make Up Rules']
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Risk Level
# Unique Values :  [ 1.  5.  2.  3.  4. nan]
# ************************************************************************************************************************************************************************************************************************************************************************************************************
# Name of the column :  Impact
# Unique Values :  ['4-Minor/Localized' '3-Moderate/Limited' '2-Significant/Large' nan]
